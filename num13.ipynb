# %% [markdown]
# # num 13

# %% [markdown]
# ##### № 27768 Апробация 04.03.26

# %% [markdown]
# Сеть задана IP-адресом 172.16.160.0 и маской сети 255.255.240.0.
#
# Сколько в этой сети IP-адресов, для которых количество единиц в их двоичной записи кратно 2?

# %%
from ipaddress import *

cnt = 0
net = ip_network("172.16.160.0/255.255.240.0", 0)
for add in net:
    bin_add = bin(int(add))[2:]
    if bin_add.count("1") % 2 == 0:
        cnt += 1
print(cnt)

# %% [markdown]
# Ответ: 2048

# %% [markdown]
# ##### № 27625 Апробация 04.03.26

# %% [markdown]
# Сеть задана IP-адресом 172.16.96.0 и маской сети 255.255.224.0.
#
# Сколько в этой сети IP-адресов, для которых количество единиц в их двоичной записи кратно 2?

# %%
from ipaddress import *

cnt = 0
net = ip_network("172.16.96.0/255.255.224.0", 0)
for add in net:
    bin_add = bin(int(add))[2:]
    if bin_add.count("1") % 2 == 0:
        cnt += 1
print(cnt)

# %% [markdown]
# Ответ: 4096

# %% [markdown]
# ##### № 25352 ЕГКР 13.12.25

# %% [markdown]
# Сеть задана IP-адресом одного из входящих неё узлов 190.202.83.62 и сетевой маской 255.255.252.0.
#
# Найдите наибольший IP-адрес в данной сети, который может быть назначен компьютеру. В ответе укажите сумму числовых значений октетов найденного IP-адреса.
#
# Например, если бы найденный адрес был равен 100.20.3.4, то в ответе следовало бы записать: 127.

# %%
from ipaddress import ip_network

net = ip_network("190.202.83.62/255.255.252.0", False)
list_add = [x for x in net.hosts()]
print(sum(int(x) for x in str(list_add[-1]).split(".")))

# %% [markdown]
# Ответ: 729
