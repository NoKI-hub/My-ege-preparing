# %% [markdown]
# ##### № 29960 Апробация 14.05.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_1.png)

# %%
x1 = 1024
y1 = 768
i1 = 30
x2 = 800
y2 = 600
i2 = 28
print((x1 * y1 * i1 - x2 * y2 * i2) / 8 / 1024 * 100)
# Out:
# 123937.5

# %% [markdown]
# Ответ: 123937

# %% [markdown]
# ##### № 29339 Открытый вариант 2026 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_2.png)

# %%
from math import ceil
k = 2
i = 8
f = 28000
t = 140
print(ceil(k * i * f * t / 1024 / 8))
# Out:
# 7657

# %% [markdown]
# Ответ: 7657

# %% [markdown]
# ##### № 28928 ЕГКР 18.04.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_3.png)

# %%
from math import floor
k = 2
f = 20000
i = 32
t = 35 * 60 + 50
quantity = 13
m_all = 339 * 1024
m_tracks = k * f * i * t / 8 / 1024
m_titles = m_all - m_tracks
print(floor(m_titles / quantity))
# Out:
# 861

# %% [markdown]
# Ответ: 861

# %% [markdown]
# ##### № 28753 Досрочная волна 2026 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_4.png)

# %%
t = 3 * 60 + 10
i = 16
k = 2
f = 12000
print(int(k * i * f * t / 8 // 1024))
# Out:
# 8906

# %% [markdown]
# Ответ: 8906

# %% [markdown]
# #####  № 27619 Апробация 04.03.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_5.png)

# %%
x = 192
y = 960
m = 90 * 1024 * 8
k = 1 - 0.15
i = m / k / x // y
print(2 ** i)
# Out:
# 16.0

# %% [markdown]
# Ответ: 16

# %% [markdown]
# ##### № 25346 ЕГКР 13.12.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num7_6.png)

# %%
i = 14
x = 1024
y = 960
quantity = 400
print(int(x * y * i * quantity / 8 / 1024 / 1024))
# Out:
# 656

# %% [markdown]
# Ответ: 656
