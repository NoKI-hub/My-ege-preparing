# %% [markdown]
# # num 1

# %% [markdown]
# ##### № 28922 ЕГКР 18.04.26 (Уровень: Базовый)

# %% [markdown]
# ![{C447CCA7-5B27-4042-AA0A-017ED7DFB14C}.png](tasks/num1_1.png)

# %%
from itertools import permutations

# Данные из таблицы (номера пунктов, соединённых дорогами)
# Каждый элемент списка содержит номера соседних пунктов для пункта с индексом+1
# Например: tab[0] = "47" означает, что пункт 1 соединён с пунктами 4 и 7
table_connections = "47 458 67 125 246 35 138 27".split()
# 1 -> 4, 7
# 2 -> 4, 5, 8
# 3 -> 6, 7
# ...

# Данные из графа (буквенные обозначения дорог на схеме)
# Каждая дорога представлена как строка из двух букв (например, "ab" - дорога между A и B)
graph_edges = "ab ah hf fe eg gb cg cb cd df".split()

# Выводим номера пунктов от 1 до 8 для наглядности
print(*range(1, 9))

# Перебираем все возможные перестановки букв A-H
# Каждая перестановка - это вариант сопоставления букв номерам пунктов
for permutation in permutations("abcdefgh"):
    # >>> permutation = "bcadefgh"
    # >>> b -> 0
    # >>> c -> 1
    # Проверяем, соответствует ли текущая перестановка данным из таблицы
    # Для каждого ребра графа (буквенная пара) проверяем, есть ли соответствующая дорога в таблице
    is_valids = []
    for first_letter, second_letter in graph_edges:
        index_for_first_letter = permutation.index(first_letter)
        number_for_second_letter = permutation.index(second_letter) + 1
        is_valid_item = str(number_for_second_letter) in table_connections[index_for_first_letter]
        is_valids.append(is_valid_item)

    is_valid = all(is_valids)


    # Если перестановка подходит, выводим её
    if is_valid:
        print(*permutation)

# %% [markdown]
# Ответ: 57

# %% [markdown]
# ##### № 28749 Досрочная волна 2026 (Уровень: Базовый)

# %% [markdown]
# ![{7F95CA5D-C022-47BC-8A11-A74034A5F99E}.png](tasks/num1_2.png)

# %%
from itertools import permutations

tab = "457 346 24 123 167 257 156".split()
pic = "аб ав бд бв ве дг дк ег ек гк".split()

print(*range(1, 9))

for var in permutations("абвгдек"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)

# %% [markdown]
# Ответ: 11

# %% [markdown]
# ##### № 28685 (Уровень: Базовый)

# %% [markdown]
# ![alt text](tasks/num1_3.png)

# %%
from itertools import permutations

tab = "24 14567 67 125 246 235 23".split()
pic = "ab ag ad bc cd df dg de gf fe".split()

print(*range(1,8))

for var in permutations("abcdefg"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)

# %% [markdown]
# Ответ: 76

# %% [markdown]
# ##### № 29951 Апробация 14.05.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/1_29951.png)

# %%
from itertools import permutations


tab = "567 348 278 27 168 15 134 235".split()
pic = "ab ah bh hf fd dc cg ge ea ec fg".split()

print(*range(1, 9))
for var in permutations("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)

# %% [markdown]
# Ответ: 26

# %% [markdown]
# ##### № 29333 Открытый вариант 2026 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/1_29333.png)

# %%
from itertools import permutations as eba


tab = "27 1567 67 5 246 2357 1236".split()
pic = "аб бв бд вд вг ве де дк ек ге".split()

print(*range(1, 8))

for var in eba("абвгдек"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7
# г в к а б д е
# к д г а б в е

# %% [markdown]
# Ответ: 9

# %% [markdown]
# ##### № 26124 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_4.png)

# %%
from itertools import permutations as per

tab = "267 138 27 568 47 148 135 246".split()
pic = "ag ah gb gf bf bd dc de eh hc fe".split()
print(*range(1, 9))

for var in per("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7 8
# e d c g a f h b

# %% [markdown]
# Ответ: 33

# %% [markdown]
# ##### № 25340 ЕГКР 13.12.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_5.png)

# %%
from itertools import permutations

tab = "368 34 126 27 67 135 458 17".split()
pic = "ac ad ag cb cg ge ef fh hd hb".split()

print(*range(1, 9))

for var in permutations("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7 8
# a e g f b c h d
# c e g f d a h b

# %% [markdown]
# Ответ: 28

# %% [markdown]
# ##### № 23738 Демоверсия 2026 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_6.png)

# %%
from itertools import permutations

tab = "258 17 56 68 138 347 26 145".split()
pic = "ac ag ad cb cg ge ef fh hb hd".split()

print(*range(1, 9))
for var in permutations("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7 8
# g e b d c h f a
# g e d b a h f c

# %% [markdown]
# Ответ: 52

# %% [markdown]
# ##### № 23547 Пересдача 03.07.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_7.png)

# %%
from itertools import permutations

tab = "24 134 267 125 47 37 356".split()
pic = "ag af gf fc ge eb bc cd bd".split()

print(*range(1, 8))

for var in permutations("abcdefg"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7
# a f c g e d b
# d c f b e a g

# %% [markdown]
# Ответ: 7

# %% [markdown]
# ##### № 23360 Резервный день 19.06.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_8.png)

# %%
from itertools import permutations

tab = "345 467 14 123567 147 24 245".split()
pic = "af fe ed dc cb bg ga gf ge gd gc".split()

print(*range(1, 8))

for var in permutations("abcdefg"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7
# c f b g d a e
# f c a g e b d

# %% [markdown]
# Ответ: 57

# %% [markdown]
# ##### № 23260 Основная волна 11.06.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_9.png)

# %%
from itertools import permutations

tab = "346 348 12 127 678 15 458 257".split()
pic = "ad ae eg dc cf fg gh ah bh bd bc".split()

print(*range(1, 9))

for var in permutations("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
        print(24 + 23)
# Out:
# 1 2 3 4 5 6 7 8
# g a e h c f b d
# 47

# %% [markdown]
# Ответ: 47

# %% [markdown]
# ##### № 23185 Основная волна 10.06.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_10.png)

# %%
from itertools import permutations

tab = "478 38 256 15 34 37 167 127".split()
pic = "ag ah hb gc bc hf fb gd de ef".split()

print(*range(1, 9))

for var in permutations("abcdefgh"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
        print(34 + 11)
# Out:
# 1 2 3 4 5 6 7 8
# f c g e d a h b
# 45

# %% [markdown]
# Ответ: 45

# %% [markdown]
# ##### № 21887 Открытый вариант 2025 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num1_11.png)

# %%
from itertools import permutations

tab = "234 136 12 157 467 25 45".split()
pic = "ce cg ge gf ea ad df fb bd".split()

print(*range(1, 8))

for var in permutations("abcdefg"):
    if all(str(var.index(x) + 1) in tab[var.index(y)] for x, y in pic):
        print(*var)
# Out:
# 1 2 3 4 5 6 7
# f d b g e a c
# g e c f d a b

# %% [markdown]
# Ответ: 37
