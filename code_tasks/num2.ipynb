# %% [markdown]
# # num 2

# %% [markdown]
# ##### №27757 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{B05C7729-C71A-454B-B3CD-AF2662DA504B}.png)

# %%
print("x y z w")
for x in range(2):
    for y in range(2):
        for z in range(2):
            for w in range(2):
                F = (not(x) and y and z and not(w)) or (not(x) and y and not(z) and not(w)) or (x and y and z and not(w))
                if F:
                    print(x, y, z, w)

# %% [markdown]
# Ответ: xwzy

# %% [markdown]
# ##### № 27614 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{319FED99-E87D-4167-889E-2E50F3DEC351}.png)

# %%
print("x y z w")
for x in range(2):
    for y in range(2):
        for z in range(2):
            for w in range(2):
                F = (not(z) and y and x and not(w)) or (not(z) and y and not(x) and not(w)) or (z and y and x and not(w))
                if F:
                    print(x, y, z, w)

# %% [markdown]
# Ответ: wzxy

# %% [markdown]
# ##### № 25341 ЕГКР 13.12.25

# %% [markdown]
# ![alt text](tasks/{35D0D6F7-A758-452D-B70F-FDFA0EC56F56}.png)

# %%
from xml.dom import xmlbuilder


print("x y z w")
for x in range(2):
    for y in range(2):
        for z in range(2):
            for w in range(2):
                F = (w == z) or not(y <= w) or not(x)
                if not(F):
                    print(x, y, z, w)

# %% [markdown]
# Ответ:zwxy

# %% [markdown]
# ##### № 29953 Апробация 14.05.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_1.png)

# %%
from itertools import *

def F(x, y, z, w):
    return not((x <= w) <= (w == z)) and y

for a, b, c, d, e in product((0, 1), repeat=5):
    table = ((a, 0, 1, 0, 1),
            (0, b, c, 0, 1),
            (d, 1, 1, e, 1))
    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[-1] for line in table):
                print(*order)
# Out:
# z w y x

# %% [markdown]
# Ответ: zwyx

# %% [markdown]
# ##### № 29334 Открытый вариант 2026 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_2.png)

# %%
from itertools import *

def F(x, y, z, w):
    return ((z <= x) <= (x == y)) or not(w)

for a, b, c, d, e in product((0, 1), repeat=5):
    table = (
        (a, 0, 1, 0, 0),
        (0, b, c, 0, 0),
        (d, 1, 1, e, 0)
    )

    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[4] for line in table):
                print(*order)
# Out:
# y x w z

# %% [markdown]
# Ответ: yxwz

# %% [markdown]
# ##### № 28923 ЕГКР 18.04.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_3.png)

# %%
from itertools import *


def F(x, y, z, w):
    return (x and not(z) and not(w)) or (x and not(z) and y)
    

for a, b, c, d, e, f, g in product((0, 1), repeat=7):
    table = (
        (1, a, b, c, 1),
        (0, d, 1, e, 1),
        (f, g, 0, 0, 1)
    )
    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[4] for line in table):
                print(*order)
# Out:
# w x y z

# %% [markdown]
# Ответ: wxyz

# %% [markdown]
# ##### № 27757 Апробация 04.03.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_4.png)

# %%
from itertools import *


def F(x, y, z, w):
    return (not(x) and y and z and not(w)) or (not(x) and y and not(z) and not(w)) or (x and y and z and not(w))


for a, b, c, d, e, f, g in product((0, 1), repeat=7):
    table = (
        (1, a, b, c, 1),
        (0, d, 1, e, 1),
        (f, 0, 0, g, 1)
    )
    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[4] for line in table):
                print(*order)
# Out:
# x w z y

# %% [markdown]
# Ответ: xwzy

# %% [markdown]
# ##### № 27614 Апробация 04.03.26 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_5.png)

# %%
from itertools import *


def F(x, y, z, w):
    return (not(z) and y and x and not(w)) or (not(z) and y and not(x) and not(w)) or (z and y and x and not(w))


for a, b, c, d, e, f, g in product((0, 1), repeat=7):
    table = (
        (a, 1, b, c, 1),
        (d, 0, 1, e, 1),
        (0, f, 0, g, 1)
    )
    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[4] for line in table):
                print(*order)
# Out:
# w z x y

# %% [markdown]
# Ответ: wzxy

# %% [markdown]
# ##### № 25341 ЕГКР 13.12.25 (Уровень: Базовый)

# %% [markdown]
# ![](tasks/num2_6.png)

# %%
from itertools import *


def F(x, y, z, w):
    return (w == z) or not(y <= w) or not(x)

for a, b, c, d, e in product((0, 1), repeat=5):
    table = (
        (a, 0, 1, 0, 0),
        (b, 1, 1, c, 0),
        (0, d, e, 0, 0)
    )
    if len(table) == len(set(table)):
        for order in permutations("xyzw"):
            if all(F(**dict(zip(order, line[:4]))) == line[4] for line in table):
                print(*order)
# Out:
# z w x y

# %% [markdown]
# Ответ: zwxy
