# %% [markdown]
# # num 14

# %% [markdown]
# ##### № 29346 Открытый вариант 2026

# %% [markdown]
# ![image copy.png](<attachment:image copy.png>)

# %%
res = 5 * 1296 ** 2021 - 4 * 216 ** 2022 + 3 * 36 ** 2023 - 2 * 6 ** 2024 - 2025
cnt = 0 

while res > 0:
    d = res % 36
    if d % 2 == 0:
        cnt += 1
    res //= 36
print(cnt)

# %% [markdown]
# Ответ: 1013

# %% [markdown]
# ##### № 27769 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{D197CB78-1430-4758-9198-E9EB58C4D414}.png)

# %%
from string import printable

for x in printable[:22]:
    f1 = int("12313" + str(x) + "57", 22)
    f2 = int("1" + str(x) + "34561", 22)
    res = f1 + f2
    if res % 21 == 0:
        print(res / 21)

# %% [markdown]
# Овтет: 140914722

# %% [markdown]
# ##### № 27626 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{94A2E016-B62A-4D79-B65C-2E6F1F11A043}.png)

# %%
def to_any_ss(x, ss):
    r = ""
    while x > 0:
        r = str(x % ss) + r
        x = x // ss
    return r


min_z = 10000000
for x in range(2031):
    res = 6 ** 2030 + 6 ** 100 - x
    res6 = to_any_ss(res, 6)
    if res6.count("0") < min_z:
        min_z = res6.count("0")
print(min_z)

# %% [markdown]
# Ответ: 1930

# %% [markdown]
# ##### № 27298 (Уровень: Средний)

# %% [markdown]
# ![alt text](tasks/{37E0CA76-BE2C-42F7-B398-DD31EC7519C0}.png)

# %%
from string import printable


for x in printable[:19]:
    r1 = int("2E" + x + "G8", 19)
    r2 = int("6F" + x + "BG", 19)
    if (r1 + r2) % 18 == 0:
        print((r1 + r2) // 9)

# %% [markdown]
# Ответ: 138804

# %% [markdown]
# ##### № 28935 ЕГКР 18.04.26 (Уровень: Базовый)

# %% [markdown]
# ![alt text](tasks/{5A8FC039-CAED-4FFA-942E-8852E53C2402}.png)

# %%
from string import printable


def value(x: str) -> int:
    return int(f"761{x}035", 23) + int(f"338{x}932", 23)


possible_values = printable[:23]

for x in possible_values:
    val = value(x)
    if val % 22 == 0:
        res = val // 22
        print(res)
        break

# %% [markdown]
# Ответ: 70045642
