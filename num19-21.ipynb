# %% [markdown]
# # num 19-21

# %% [markdown]
# ##### № 22066 (Уровень: Базовый)

# %% [markdown]
# Ответ:
# - 40
# - 20 29
# - 36

# %%
def f(a, b, m):
    if a + b >= 100: return m % 2 == 0
    if m == 0: return 0
    h = [f(a + 3, b, m - 1), f(a, b + 3, m - 1), f(a * 2, b, m - 1), f(a, b * 2, m - 1)]
    return any(h) if m % 2 != 0 else all(h)

print([s for s in range(1, 83) if f(17, s, 2)])
print([s for s in range(1, 83) if not f(17, s, 1) and f(17, s, 3)])
print([s for s in range(1, 83) if not f(17, s, 2) and f(17, s, 4)])

# %% [markdown]
# ##### № 23565 Пересдача 03.07.25 (Уровень: Базовый)

# %% [markdown]
# Ответ:
# - 48
# - 51 52
# - 54

# %%
def f(s, m):
    if s <= 15: return m % 2 == 0
    if m == 0: return 0
    h = [f(s - 3, m - 1), f(s - 8, m - 1), f(s // 3, m - 1)]
    return any(h) if m % 2 != 0 else all(h)

print([s for s in range(16, 100) if f(s, 2)])
print([s for s in range(16, 100) if not f(s, 1) and f(s, 3)])
print([s for s in range(16, 100) if not f(s, 2) and f(s, 4)])

# %% [markdown]
# ##### № 23759 Демоверсия 2026 (Уровень: Базовый)

# %% [markdown]
# Ответ:
# - 124
# - 127 128
# - 132

# %%
from math import floor


def f(s, m):
    if s <= 30: return m % 2 == 0
    if m == 0: return 0
    h = [f(s - 3, m - 1), f(s - 5, m - 1), f(floor(s // 4), m - 1)]
    return any(h) if m % 2 != 0 else all(h)


print([s for s in range(31, 300) if f(s, 2)])
print([s for s in range(31, 300) if not f(s, 1) and f(s, 3)])
print([s for s in range(31, 300) if not f(s, 2) and f(s, 4)])

# %% [markdown]
# ##### № 22438 (Уровень: Базовый)

# %% [markdown]
# Ответ:
# - 49
# - 50 98
# - 101

# %%
from math import ceil


def f(s, m):
    if s <= 23: return m %  2 == 0
    if  m == 0: return 0
    h = [f(s - 3, m - 1), f(s - 5, m - 1), f(ceil(s / 2), m - 1)]
    return any(h) if m % 2 != 0 else all(h)


print([s for s in range(24, 10000) if f(s, 2)])
print([s for s in range(24, 10000) if not f(s, 1) and f(s, 3)])
print([s for s in range(24, 10000) if not f(s, 2) and f(s, 4)])

# %% [markdown]
# ##### № 23278 Основная волна 11.06.25 (Уровень: Базовый)

# %% [markdown]
# Ответ:
# - 51
# - 54 55
# - 57

# %%
def f(s, m):
    if s <= 16: return m % 2 == 0
    if m == 0: return 0
    h = [f(s - 3, m - 1), f(s - 8, m - 1), f(s // 3, m - 1)]
    return any(h) if m % 2 != 0 else all(h)


print([s for s  in range(17, 100) if f(s, 2)])
print([s for s  in range(17, 100) if not f(s, 1) and f(s, 3)])
print([s for s  in range(17, 100) if not f(s, 2) and f(s, 4)])

# %% [markdown]
# ##### № 28704 (Уровень: Базовый)

# %% [markdown]
# ![alt text](tasks/{F0345330-AAC7-4B22-8C2C-C5D12662E5D0}.png)

# %%
def f(s1, s2, m):
    if s1 * s2 >= 516: return m % 2 == 0
    if m == 0: return 0
    h = [f(s1 + 3, s2, m - 1), f(s1 + 13, s2, m - 1), f(s1, s2 + 3, m - 1), f(s1, s2 + 13, m - 1)]
    return any(h) if m % 2 != 0 else all(h)

def f1(s1, s2, m):
    if s1 * s2 >= 516: return m % 2 == 0
    if m == 0: return 0
    h = [f(s1 + 3, s2, m - 1), f(s1 + 13, s2, m - 1), f(s1, s2 + 3, m - 1), f(s1, s2 + 13, m - 1)]
    return any(h) if m % 2 != 0 else any(h)

print(len([s for s in range(1, 74) if f1(7, s, 2)]))
print(*[s for s in range(1, 74) if not f(7, s, 1) and f(7, s, 3)][:2])
print([s for s in range(1, 74) if not f(7, s, 2) and f(7, s, 4)][-1])

# %% [markdown]
# Ответ:
# - 58
# - 10 11
# - 19

# %% [markdown]
# ##### № 27774 Апробация 04.03.26 (Уровень: Базовый)

# %% [markdown]
# ![alt text](tasks/{F7E2066E-569C-41E6-8A55-079998493506}.png)

# %%
def f(s1, s2, m):
    if s1 + s2 >= 207: return m % 2 == 0
    if m == 0: return 0
    h = [f(s1 + 1, s2, m - 1), f(s1 * 2, s2, m - 1), f(s1, s2 + 1, m - 1), f(s1, s2 * 2, m - 1)]
    return any(h) if m % 2 != 0 else all(h)

print([s for s in range(1, 190) if f(17, s, 2)])
print([s for s in range(1, 190) if not f(17, s, 1) and f(17, s, 3)])
print([s for s in range(1, 190) if not f(17, s, 2) and f(17, s, 4)])

# %% [markdown]
# Ответ:
# - 48
# - 86 94
# - 85

# %% [markdown]
# ##### № 27631 Апробация 04.03.26 (Уровень: Базовый)

# %% [markdown]
# ![alt text](tasks/{D0465C93-EE8E-452C-BFD5-28CCB26C55DC}.png)

# %%
def f(s1, s2, m):
    if s1 + s2 >= 211: return m % 2 == 0
    if m == 0: return 0
    h = [f(s1 + 1, s2, m - 1), f(s1 * 2, s2, m - 1), f(s1, s2 + 1, m - 1), f(s1, s2 * 2, m - 1)]
    return any(h) if m % 2 != 0 else all(h)

print([s for s in range(1, 194) if f(s, 17, 2)])
print([s for s in range(1, 194) if not f(s, 17, 1) and f(s, 17, 3)])
print([s for s in range(1, 194) if not f(s, 17, 2) and f(s, 17, 4)])

# %% [markdown]
# Ответ:
# - 49
# - 88 96
# - 87
