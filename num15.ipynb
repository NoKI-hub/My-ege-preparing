# %% [markdown]
# # num 15

# %% [markdown]
# ##### № 27770 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{1B8FD39D-2E37-4D49-8EF2-078FBAB27B2A}.png)

# %%
def dell(n, m):
    if n % m == 0: return True
    else: return False

for a in range(232, 1, -1):
    if all(dell(x, 21) <= ((not(dell(x, a))) <= (not(dell(x, 77)))) for x in range(1, 100000)):
        # pass
        print(a)
        break

# %% [markdown]
# Ответ: 231

# %% [markdown]
# ##### № 27627 Апробация 04.03.26

# %% [markdown]
# ![alt text](tasks/{FB3FE5FC-B21D-42E8-8D01-D9B95944582A}.png)

# %%
def dell(n, m):
    return True if n % m == 0 else False

for a in range(10000, 1, -1):
    if all(dell(x, 25) <= ((not(dell(x, a))) <= (not(dell(x, 60)))) for x in range(1, 10000)):
        print(a)
        break

# %% [markdown]
# Ответ: 300
